# %%
years_list = [2001,2002,2003,2004,2005]
years_list[3]
max(years_list)
print("Birth year and years after: ",years_list)
print("My third birthday: ",years_list[3])
print("My oldest birthday: ",max(years_list))
# Out:
# Birth year and years after:  [2001, 2002, 2003, 2004, 2005]
# My third birthday:  2004
# My oldest birthday:  2005

# %%
things = list(["mozzarella","cinderella","salmonella"])
for i in things:
    print(i.capitalize())
# Out:
# Mozzarella
# Cinderella
# Salmonella

# %%
def good():
    return ["Harry","Ron","Hermione"]

# %%
get_odd = [number for number in range(10) if number %2 !=0]
print(get_odd)
# Out:
# [1, 3, 5, 7, 9]

# %%
seconds_per_hour = 60 * 60
seconds_per_day = seconds_per_hour * 24
a = seconds_per_day / seconds_per_hour
b = seconds_per_day // seconds_per_hour

print("seconds per hour: ",seconds_per_hour) 
print("seconds per day: ",seconds_per_day)
print("seconds per day divided by seconds per hour:", a)
print("seconds per day divided by seconds per hour:", b)
# Out:
# seconds per hour:  3600
# seconds per day:  86400
# seconds per day divided by seconds per hour: 24.0
# seconds per day divided by seconds per hour: 24
